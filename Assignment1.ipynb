# %%
from bs4 import BeautifulSoup
import requests
import re
import pandas as pd

# Downloading IMDB's The Flash's page
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36'}
url = 'https://www.imdb.com/title/tt3107288/episodes?ref_=tt_eps_sm'
response = requests.get(url,headers=headers)
soup = BeautifulSoup(response.text, "html.parser")

# Downloading timesjobs' software engineer job search page
url2 = 'https://www.timesjobs.com/candidate/job-search.html?searchType=personalizedSearch&from=submit&txtKeywords=Software+Engineer&txtLocation=    '
response2 = requests.get(url2,headers=headers)
soup2 = BeautifulSoup(response2.text, "html.parser")

# %%
# Scraping The Flash's IMDB's page
links=[]
Title=[]
Description=[]
Date=[]
Rating=[]
Rate=[]
Rate2=[]
images=[]
iconLink=[]
icon=[]

for t in soup.select('a.sc-1318654d-8'):
  Title.append(t.get_text())
for a in soup.select('a.sc-1318654d-8'):
  links.append(a.attrs.get('href'))
for t in soup.select('div.ipc-html-content-inner-div'):
  Description.append(t.get_text())
for t in soup.select('span.sc-1318654d-10'):
  Date.append(t.get_text())
for t in soup.select('span.ipc-rating-star--imdb'):
  Rating.append(t.get_text()[0:6])
for t in soup.select('span.ipc-rating-star--voteCount'):
  Rate2.append(t.get_text())
for t in soup.select('div.ipc-media img.ipc-image'):
  images.append(t.attrs.get('src'))


# Scraping timesjobs.com selected web (software engineer job search page)
company=[]
details=[]
time=[]
duration=[]
locations=[]
jobdescription=[]

for t in soup2.select('h3.joblist-comp-name'):
  company.append(t.get_text().strip())
for t in soup2.select('ul.list-job-dtl a'):
  details.append(t.attrs.get('href'))
for t in soup2.select('span.sim-posted'):
  time.append(t.get_text().strip())
for t in soup2.select('ul.top-jd-dtl'):
  duration.append(t.get_text().strip()[11:20])
for t in soup2.select('ul.top-jd-dtl'):
  locations.append(t.get_text().strip()[34:])
for t in soup2.select('span.srp-skills'):
  jobdescription.append(t.get_text().strip())

df = pd.DataFrame(
  {'Title': Title[0:23],
    'Description' : Description[0:23],
    'Links': links[0:23],
    'Date' : Date[0:23],
    'Rating' : Rating[0:23],
    'Views' : Rate2[0:23],
    'Image' : images[0:23],
  })

df.to_csv('IMDBTheFlash.csv', index=False)

df2 = pd.DataFrame(
    {'Company': company[0:23],
     'Details' : details[0:23],
     'Time': time[0:23],
     'Duration' : duration[0:23],
     'Locations' : locations[0:23],
     'Key Skills' : jobdescription[0:23],
    })

df2.to_csv('TimesJobs.csv', index=False)

df = pd.DataFrame(
    {'Title': Title[0:23],
     'Description' : Description[0:23],
     'Links': links[0:23],
     'Date' : Date[0:23],
     'Rating' : Rating[0:23],
     'MaxRating' : Rate[0:23],
     'Views' : Rate2[0:23],
     'Image' : images[0:23],
    })

df.to_csv('IMDBTheFlash.csv', index=False)

df2 = pd.DataFrame(
    {'Company': company[0:23],
     'Details' : details[0:23],
     'Time': time[0:23],
     'Duration' : duration[0:23],
     'Locations' : locations[0:23],
     'JobDesc' : jobdescription[0:23],
    })

df2.to_csv('TimesJobs.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\ruysj\OneDrive\Documents\FODS\Assignment1.ipynb Cell 2 line 7
#      <a href='vscode-notebook-cell:/c%3A/Users/ruysj/OneDrive/Documents/FODS/Assignment1.ipynb#X12sZmlsZQ%3D%3D?line=61'>62</a> df2 = pd.DataFrame(
#      <a href='vscode-notebook-cell:/c%3A/Users/ruysj/OneDrive/Documents/FODS/Assignment1.ipynb#X12sZmlsZQ%3D%3D?line=62'>63</a>     {'Company': company[0:23],
#      <a href='vscode-notebook-cell:/c%3A/Users/ruysj/OneDrive/Documents/FODS/Assignment1.ipynb#X12sZmlsZQ%3D%3D?line=63'>64</a>      'Details' : details[0:23],
#    (...)
#      <a href='vscode-notebook-cell:/c%3A/Users/ruysj/OneDrive/Documents/FODS/Assignment1.ipynb#X12sZmlsZQ%3D%3D?line=67'>68</a>      'JobDesc' : jobdescription[0:23],
# ...
